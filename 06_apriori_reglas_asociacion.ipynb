# %% [markdown]
# # Ejemplo 6: Reglas de Asociación – Algoritmo A priori
#
# Este Jupyter Notebook implementa el algoritmo A priori,
# utilizado para descubrir relaciones frecuentes entre elementos
# en un conjunto de datos.

# %%
# !pip install mlxtend

import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
# Out:
# Requirement already satisfied: mlxtend in c:\users\uva30\anaconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\uva30\anaconda3\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\uva30\anaconda3\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\uva30\anaconda3\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\uva30\anaconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\uva30\anaconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\uva30\anaconda3\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\uva30\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\uva30\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\uva30\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\uva30\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\uva30\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)

# %% [markdown]
# ## Conjunto de datos
#
# Se define un conjunto de transacciones que representan la compra
# de productos por diferentes clientes.

# %%
# Datos de ejemplo (transacciones)
data = pd.DataFrame({
    'Pan': [1, 0, 1, 1, 0],
    'Leche': [1, 1, 1, 0, 1],
    'Mantequilla': [0, 1, 1, 1, 0],
    'Huevos': [1, 1, 0, 1, 1]
})

data
# Out:
#    Pan  Leche  Mantequilla  Huevos
# 0    1      1            0       1
# 1    0      1            1       1
# 2    1      1            1       0
# 3    1      0            1       1
# 4    0      1            0       1

# %% [markdown]
# ## Búsqueda de conjuntos frecuentes
#
# Se aplica el algoritmo A priori para encontrar combinaciones
# frecuentes de productos.

# %%
frequent_itemsets = apriori(
    data,
    min_support=0.4,
    use_colnames=True
)

frequent_itemsets
# Out:
# C:\Users\uva30\anaconda3\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:175: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#    support               itemsets
# 0      0.6                  (Pan)
# 1      0.8                (Leche)
# 2      0.6          (Mantequilla)
# 3      0.8               (Huevos)
# 4      0.4           (Pan, Leche)
# 5      0.4     (Pan, Mantequilla)
# 6      0.4          (Pan, Huevos)
# 7      0.4   (Mantequilla, Leche)
# 8      0.6        (Huevos, Leche)
# 9      0.4  (Huevos, Mantequilla)

# %% [markdown]
# ## Generación de reglas de asociación
#
# A partir de los conjuntos frecuentes se generan reglas
# utilizando la métrica de confianza.

# %%
rules = association_rules(
    frequent_itemsets,
    metric="confidence",
    min_threshold=0.7
)

rules
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Leche)    (Huevos)                 0.8                 0.8      0.6
# 1    (Huevos)     (Leche)                 0.8                 0.8      0.6
#
#    confidence    lift  representativity  leverage  conviction  zhangs_metric  \
# 0        0.75  0.9375               1.0     -0.04         0.8          -0.25
# 1        0.75  0.9375               1.0     -0.04         0.8          -0.25
#
#    jaccard  certainty  kulczynski
# 0      0.6      -0.25        0.75
# 1      0.6      -0.25        0.75

# %% [markdown]
# ### Interpretación de resultados
#
# El algoritmo A priori identificó relaciones frecuentes entre productos.
# Estas reglas pueden utilizarse para análisis de canasta de mercado
# y sistemas de recomendación.
